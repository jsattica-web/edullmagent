# %% [markdown]
# # [실습] LangGraph 워크플로우 패턴
#
# LangGraph의 Graph 패턴을 활용하여 다양한 워크플로우를 구현합니다.
#
# | 패턴 | 설명 | 사용 API |
# |------|------|----------|
# | Router | 입력을 분류하여 조건부 라우팅 | `add_conditional_edges()` |
# | Fan-in / Fan-out | 여러 노드를 병렬 실행 후 결과 합산 | 다중 `add_edge(START, ...)` |
# | Map-Reduce | 동적 개수의 워커를 병렬 생성 | `Send()` API |
# | Evaluator-Optimizer | 생성하고 평가한 뒤 다듬는 반복 루프 | 조건부 엣지 + 루프 |

# %% [markdown]
# ## 학습 목표
#
# 1. LangGraph `StateGraph`의 기본 구조(상태, 노드, 엣지) 복습
# 2. Router 패턴: `add_conditional_edges()`를 활용한 조건부 라우팅 구현
# 3. Map-Reduce 패턴: `Send()` API를 통한 동적 병렬 처리 구현
# 4. 각 패턴의 적절한 사용 상황 이해

# %% [markdown]
# ## 0. 환경 설정

# %%
import os
import operator
from typing import List
from typing_extensions import TypedDict, Annotated, Literal
from pydantic import BaseModel, Field
from dotenv import load_dotenv

load_dotenv('.env', override=True)

from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langfuse.langchain import CallbackHandler
callbacks = [CallbackHandler()] if os.environ.get('LANGFUSE_PUBLIC_KEY') else []

# LLM 설정: 워크플로우는 짧고 반복적인 호출이 많아, 샘플링 폭을 좁힌 가벼운 vLLM 설정을 사용합니다.
from select_model import load_model

light_model = load_model(platform='vllm', enable_thinking=False, max_tokens=16384, temperature=0.7, top_p=0.80, presence_penalty=1.5, extra_body={"top_k": 20, "min_p": 0.0, "repetition_penalty": 1.0})
llm = light_model

print('환경 설정 완료')
# Out:
# 환경 설정 완료

# %% [markdown]
# ---
# ## 1. Router 패턴
#
# 라우터는 State의 값을 기준으로 조건부 분기하여, 입력의 종류에 따라 다른 노드를 실행하는 패턴입니다.
# 주로 의도 분류(Intent Classification)에 활용됩니다.
#
# 노드의 리턴값은 역할에 따라 두 가지로 나뉩니다.
# 분기를 결정하는 분류 노드는 `response_format`으로 구조화된 출력(`structured_response`)을 받아 분류 결과를 State에 넣고,
# 답변처럼 텍스트가 산출물인 노드는 마지막 메시지의 `.text`를 State에 넣습니다.
#
# ### 시나리오: 보험 고객 문의 라우팅
#
# 고객 문의를 자동으로 분류하여, 분류 결과에 따라 전문 상담 채널로 연결합니다.
#
# - PRODUCT: 보험 상품 안내는 상품 안내 채널로
# - CLAIM: 보험금 청구/심사는 청구 안내 채널로
# - CONTRACT: 계약 변경/해지는 계약 관리 채널로
# - GENERAL: 일반 문의는 일반 상담 채널로
#
# `route` 노드를 통해 문의를 분류하고, 분류 결과에 따라 다른 채널로 라우팅하는 패턴입니다.

# %%
# 분류 결과 스키마
class Classification(BaseModel):
    category: Literal["PRODUCT", "CLAIM", "CONTRACT", "GENERAL"] = Field(
        description="고객 문의 분류 결과"
    )
    

# 라우터 상태 정의
class RouterState(TypedDict):
    query: str
    classification: str
    answer: str

print(f'RouterState 필드: {list(RouterState.__annotations__.keys())}')
# Out:
# RouterState 필드: ['query', 'classification', 'answer']

# %%
classifier = create_agent(
    llm,
    tools=[],
    system_prompt='''당신은 보험회사의 고객 문의를 분류하는 봇입니다.

1) 보험 상품 관련 질문 (가입, 상품 추천, 보장 내용 등): 'PRODUCT'
2) 보험금 청구/심사 관련 질문 (청구 방법, 필요 서류, 심사 기간 등): 'CLAIM'
3) 계약 변경 관련 질문 (계약 변경, 해지, 부활, 수익자 변경 등): 'CONTRACT'
4) 그 외 일반 질문: 'GENERAL'
''',
    response_format=Classification,
)


def route(state: RouterState):
    """고객 문의를 분류하는 라우터. structured_response로 분류 결과를 받는다."""
    result = classifier.invoke({'messages': [HumanMessage(f"고객 질문: {state['query']}")]})
    return {'classification': result['structured_response'].category}


def make_handler(system_prompt):
    """system_prompt만 다른 답변 노드를 만든다. 에이전트는 state의 query만 본다."""
    agent = create_agent(llm, tools=[], system_prompt=system_prompt)

    def handler(state: RouterState):
        result = agent.invoke({'messages': [HumanMessage(state['query'])]})
        return {'answer': result['messages'][-1].text}

    return handler


handle_product = make_handler('''당신은 보험 상품 안내 전문가입니다.
고객의 상황에 맞는 보험 상품을 친절하게 안내하세요.
실제 상품이 아닌 일반적인 상품 가이드라인을 안내합니다.
답변은 최대 2문단, 10문장 이내로 작성하세요.''')

handle_claim = make_handler('''당신은 보험금 청구 안내 전문가입니다.
필요 서류와 절차를 친절하게 안내하세요.
답변은 최대 2문단, 10문장 이내로 작성하세요.''')

handle_contract = make_handler('''당신은 계약 관리 전문가입니다.
변경 절차와 주의사항을 안내하세요.
답변은 최대 2문단, 10문장 이내로 작성하세요.''')

handle_general = make_handler('''당신은 친절한 보험 상담사입니다.
정확하고 친절하게 답변하세요.
답변은 최대 2문단, 10문장 이내로 작성하세요.''')


def route_decision(state: RouterState):
    """분류 결과에 따라 적절한 핸들러로 라우팅"""
    return {
        'PRODUCT': 'handle_product',
        'CLAIM': 'handle_claim',
        'CONTRACT': 'handle_contract',
    }.get(state['classification'], 'handle_general')

print('노드 함수 정의 완료')
# Out:
# 노드 함수 정의 완료

# %%
builder = StateGraph(RouterState)

# 노드 추가
builder.add_node("route", route)
builder.add_node("handle_product", handle_product)
builder.add_node("handle_claim", handle_claim)
builder.add_node("handle_contract", handle_contract)
builder.add_node("handle_general", handle_general)

# 엣지 설정
builder.add_edge(START, "route")
builder.add_conditional_edges("route", route_decision, {
    "handle_product": "handle_product",
    "handle_claim": "handle_claim",
    "handle_contract": "handle_contract",
    "handle_general": "handle_general",
})
builder.add_edge("handle_product", END)
builder.add_edge("handle_claim", END)
builder.add_edge("handle_contract", END)
builder.add_edge("handle_general", END)

router_graph = builder.compile()

# 그래프 시각화
router_graph

# %%
# 상품 문의 테스트
query = '30대 직장인인데, 암보험에 가입하려고 합니다. 어떤 상품이 좋을까요?'
result = router_graph.invoke({'query': query},
    config={'callbacks': callbacks})
print(f'분류: {result["classification"]}')
print(f'답변:\n{result["answer"]}')
# Out:
# 분류: PRODUCT
# 답변:
# 30대 직장인이라면 아직 건강 상태가 비교적 양호한 시기를 활용해, 암 발병 시 큰 치료비 부담을 덜어줄 수 있는 '실손의료비 보장'과 '암 진단금'이 결합된 상품을 우선적으로 고려해 보세요. 특히 최근에는 암 생존율이 높아지면서 완치 후 재발이나 합병증에 대비한 장기적 보장 기능이 포함된 제품이 인기를 끌고 있으니, 단순 진단비 지급뿐만 아니라 지속적인 치료비를 지원해주는지 꼼꼼히 비교하시는 것이 중요합니다.
#
# 또한 직장인이시라면 회사에서 제공하는 복리후생 혜택이나 단체보험 내용을 먼저 확인하여 중복 보장을 피하는 것도 좋은 전략입니다. 보험료 부담을 줄이면서도 핵심 보장은 유지하려면, 과도한 특약 가입보다는 기본 담보의 충실함과 향후 의료 기술 발전에 유연하게 대응할 수 있는 갱신형 또는 종신형 중 본인의 생활 패턴에 맞는 유형을 선택하시기 바랍니다.

# %%
# 청구 문의 테스트
query = '교통사고로 입원했는데 보험금 청구하려면 어떻게 해야 하나요?'
result = router_graph.invoke(
    {'query': query},
    config={'callbacks': callbacks}
)
print(f'분류: {result["classification"]}')
print(f'답변:\n{result["answer"]}')
# Out:
# 분류: CLAIM
# 답변:
# 먼저 사고 발생 즉시 보험사에 통보하고, 병원 치료 과정에서 진료비 영수증과 진단서 등 모든 의료 관련 증빙 자료를 꼼꼼히 보관해 두셔야 합니다. 특히 입원 기록이 포함된 진료비 내역서와 의사가 작성한 진단서는 보상 심사의 핵심 근거가 되므로 분실하지 않도록 주의하시기 바랍니다.
#
# 청구 시에는 사고 사실을 증명하는 교통사고확인원(또는 과실 비율이 명시된 확인원)과 본인의 신분증, 통장 사본, 그리고 위에서 준비한 모든 의료 증빙 서류를 보험사 지정 양식에 맞춰 제출하시면 됩니다. 최근에는 모바일 앱이나 인터넷 포털을 통해 비대면으로 간편하게 신청할 수 있으니, 소속 보험사의 고객센터나 홈페이지에서 정확한 접수 방법을 확인하여 빠르고 정확하게 처리하시길 권장합니다.

# %%
# 일반 문의 테스트
query = '오늘 날씨가 어때요?'
result = router_graph.invoke(
    {'query': query},
    config={'callbacks': callbacks}
)
print(f'분류: {result["classification"]}')
print(f'답변:\n{result["answer"]}')
# Out:
# 분류: GENERAL
# 답변:
# 안녕하세요! 저는 AI 보험 상담사로서 실시간 날씨 정보를 직접 확인할 수는 없어 아쉽네요. 하지만 날씨가 좋지 않을 때는 외출 시 안전에 각별히 주의하시고, 갑작스러운 건강 변화에 대비해 의료비 부담을 줄일 수 있는 보장 계획을 살펴보는 것도 좋은 방법입니다.
#
# 건강과 안전은 어떤 날씨에도 중요하므로, 현재 가입하신 보험이 충분한 보장을 제공하는지 확인해보시길 권해 드립니다. 더 궁금한 점이 있거나 보험 관련 조언이 필요하시면 언제든 편하게 말씀해 주세요.

# %% [markdown]
# ---
# ## 2. Fan-in / Fan-out 패턴
#
# 조건분기가 아닌 일반 그래프의 경우에도, 여러 노드가 동시에 실행될 수 있습니다.
# Fan-in / Fan-out 패턴은 분기 없이도 노드를 병렬적으로 실행한 후, 결과를 합치는 패턴입니다.
#
# ### 시나리오: 종합 코드 리뷰
#
# 하나의 코드를 세 가지 관점에서 동시에 리뷰하고, 결과를 종합합니다.
# 세 리뷰 노드는 서로의 결과를 보지 못하고, State의 code만 봅니다.
#
# - 성능 리뷰어: 시간 복잡도, 메모리 효율성, 알고리즘 적절성 분석
# - 보안 리뷰어: SQL Injection, XSS, 인증 관련 취약점 분석
# - 유지보수성 리뷰어: 네이밍, 코드 구조, 테스트 용이성 분석

# %%
class CodeReviewState(TypedDict):
    code: str
    performance_review: str
    security_review: str
    maintainability_review: str
    final_review: str

print(f'CodeReviewState 필드: {list(CodeReviewState.__annotations__.keys())}')
# Out:
# CodeReviewState 필드: ['code', 'performance_review', 'security_review', 'maintainability_review', 'final_review']

# %%
def make_reviewer(field, system_prompt):
    """관점별 리뷰 노드를 만든다. 에이전트는 state의 code만 본다."""
    agent = create_agent(llm, tools=[], system_prompt=system_prompt)

    def reviewer(state: CodeReviewState):
        result = agent.invoke({'messages': [HumanMessage(f"코드:\n```\n{state['code']}\n```")]})
        return {field: result['messages'][-1].text}

    return reviewer


review_performance = make_reviewer('performance_review', '''당신은 시니어 백엔드 개발자입니다.
주어진 코드를 성능 관점에서 리뷰하세요.

분석 항목:
- 시간 복잡도 / 공간 복잡도
- 불필요한 연산이나 반복
- 메모리 누수 가능성
- DB 쿼리 최적화 (해당 시)

간결하게 작성하세요.''')

review_security = make_reviewer('security_review', '''당신은 보안 전문가입니다.
주어진 코드를 보안 관점에서 리뷰하세요.

분석 항목:
- SQL Injection, XSS 등 보안 취약점
- 인증/인가(비밀번호, API 키 등) 처리
- 입력값 검증 여부

간결하게 작성하세요.''')

review_maintainability = make_reviewer('maintainability_review', '''당신은 클린 코드 전문가입니다.
주어진 코드를 유지보수성 관점에서 리뷰하세요.

분석 항목:
- 변수/함수 네이밍
- 코드 구조와 가독성
- 단일 책임 원칙 준수 여부
- 테스트 용이성

간결하게 작성하세요.''')


synthesizer = create_agent(
    llm,
    tools=[],
    system_prompt='''세 관점의 코드 리뷰를 종합하여 최종 리뷰를 작성하세요.
각 관점의 주요 지적사항을 정리하고, 보완 우선순위 3개를 제시하세요.''',
)


def summarize_review(state: CodeReviewState):
    """세 관점의 리뷰를 종합하는 노드. 원본 코드와 세 리뷰를 모두 본다."""
    report = f'''## 원본 코드
```
{state['code']}
```

## 성능 리뷰
{state['performance_review']}

## 보안 리뷰
{state['security_review']}

## 유지보수성 리뷰
{state['maintainability_review']}'''
    result = synthesizer.invoke({'messages': [HumanMessage(report)]})
    return {'final_review': result['messages'][-1].text}

print('코드 리뷰 노드 정의 완료')
# Out:
# 코드 리뷰 노드 정의 완료

# %%
builder = StateGraph(CodeReviewState)

builder.add_node("review_performance", review_performance)
builder.add_node("review_security", review_security)
builder.add_node("review_maintainability", review_maintainability)
builder.add_node("summarize_review", summarize_review)

# Fan-out: START에서 세 리뷰어로 동시 분기
builder.add_edge(START, "review_performance")
builder.add_edge(START, "review_security")
builder.add_edge(START, "review_maintainability")

# Fan-in: 세 리뷰어 결과가 모두 모이면 summarize_review로 합류
builder.add_edge("review_performance", "summarize_review")
builder.add_edge("review_security", "summarize_review")
builder.add_edge("review_maintainability", "summarize_review")
builder.add_edge("summarize_review", END)

code_review_graph = builder.compile()

# 그래프 시각화
code_review_graph

# %%
from stream_utils import stream_workflow

# 보안 취약점이 있는 코드 (보험료 계산 API 예시)
sample_code = '''
def calculate_premium(user_id, product_code):
    # DB에서 사용자 정보 조회
    query = f"SELECT * FROM users WHERE id = {user_id}"
    user = db.execute(query).fetchone()

    # 상품 정보 조회
    product = db.execute(f"SELECT * FROM products WHERE code = '{product_code}'").fetchone()

    # 나이 계산
    age = 2025 - int(user['birth_year'])

    # 보험료 계산
    base_premium = product['base_price']
    if age > 40:
        premium = base_premium * 1.5
    else:
        premium = base_premium

    print(f"User {user['name']} premium: {premium}")
    return premium
'''

# 세 리뷰어가 병렬 실행되며 ▶ 노드 시작 마커가 인터리브되어 출력됩니다.
# Fan-in 노드(summarize_review)는 셋이 모두 끝나야 시작됩니다.
result = await stream_workflow(
    code_review_graph,
    {'code': sample_code},
    config={'callbacks': callbacks},
)
# Out:
# ▶ [review_maintainability]
#
# ▶ [review_performance]
#
# ▶ [review_security]
#    ↳ security_review="제공된 코드에는 심각한 보안 취약점이 다수 존재합니다. 주요 분석 결과는 다음과 같습니다.  1.  **SQL Injection (심각)**  ..."
#    ↳ maintainability_review="### 코드 리뷰: `calculate_premium`  #### 1. 변수/함수 네이밍 - **문제점**: 함수명 `calculate_prem..."
#    ↳ performance_review="시니어 백엔드 개발자 관점에서 해당 코드의 성능 및 보안 리뷰입니다.  ### 1. 치명적 보안 취약점 (SQL Injection) *   **..."
#
# ▶ [summarize_review]
#    ↳ final_review="제시된 세 가지 관점(성능, 보안, 유지보수성)의 리뷰를 종합하여 최종 코드 리뷰 보고서와 보완 우선순위 3가지를 정리해 드립니다.  ---  ..."

# %%
from IPython.display import Markdown

# 최종 종합 리뷰 확인
Markdown(result['final_review'])
# Out:
# 제시된 세 가지 관점(성능, 보안, 유지보수성)의 리뷰를 종합하여 최종 코드 리뷰 보고서와 보완 우선순위 3가지를 정리해 드립니다.
#
# ---
#
# # 📊 종합 코드 리뷰 보고서: `calculate_premium` 함수
#
# ## 1. 주요 지적사항 요약
#
# ### 🔴 치명적 이슈 (Critical)
# 1.  **SQL Injection 취약점 (보안)**
#     *   `f-string`을 사용하여 쿼리를 동적으로 생성하고 있습니다. 이는 공격자가 임의의 SQL 명령어를 삽입하여 데이터를 탈취하거나 삭제할 수 있는 심각한 보안 허점입니다.
# 2.  **권한 검증 부재 (보안/비즈니스)**
#     *   현재 코드는 `user_id`만으로 동작하며, 해당 사용자가 자신의 정보나 상품을 조회할 권한이 있는지(Authorization) 확인하는 로직이 없습니다. ID만 알면 타인의 보험료를 조회할 수 있는 구조입니다.
# 3.  **단일 책임 원칙(SRP) 위반 및 테스트 불가 (유지보수성)**
#     *   한 함수 내에서 DB 접근, 비즈니스 로직 계산, 로그 출력이 혼재되어 있어 유지보수가 어렵고 단위 테스트(Unit Test)가 불가능합니다. 특히 `db` 객체와 `print`에 직접 의존하고 있어 Mocking이 어렵습니다.
#
# ### 🟡 개선 필요 사항 (High Priority)
# 1.  **불필요한 데이터 조회 및 성능 저하 (성능)**
#     *   `SELECT *`로 불필요한 컬럼까지 로드하여 네트워크 대역폭과 메모리를 낭비합니다. 또한 두 테이블을 순차적으로 조회(RTT 증가)하는 대신 `JOIN`을 통해 한 번의 쿼리로 최적화해야 합니다.
# 2.  **하드코딩된 값(Magic Numbers) 사용 (유지보수성)**
#     *   기준 연도(`2025`), 가중치(`1.5`) 등이 코드 내에 직접 하드코딩되어 있어 향후 요구사항 변경 시 수정 범위가 넓어지고 오류 발생 위험이 높습니다. 상수로 추출해야 합니다.
# 3.  **예외 처리 및 입력 검증 부재 (안정성)**
#     *   `fetchone()` 결과가 `None`일 경우(`KeyError` 등) 또는 타입 변환 오류(`ValueError`) 시 시스템이 비정상 종료될 수 있습니다. 또한 입력값(Type Check) 검증이 누락되어 있습니다.
#
# ### 🟢 권장 사항 (Medium/Low Priority)
# 1.  **로그 출력 방식 변경**
#     *   프로덕션 환경에서 `print()`는 I/O 오버헤드를 발생시키며 디버깅 용도로만 남겨두어야 합니다. 적절한 로깅 프레임워크(Logging Framework)를 사용해야 합니다.
# 2.  **데이터베이스 커넥션 관리**
#     *   명시적인 커넥션 닫기 또는 컨텍스트 매니저(`with`) 사용을 권장하여 리소스 누수를 방지해야 합니다.
#
# ---
#
# ## 2. 보완 우선순위 TOP 3
#
# 개발팀에서 가장 먼저 해결해야 할 상위 3가지 과제는 다음과 같습니다.
#
# ### 1순위: SQL Injection 제거 및 파라미터화된 쿼리 적용
# *   **이유:** 보안상 치명적인 취약점이므로 즉시 패치해야 하는 최우선 항목입니다.
# *   **행동 지침:** 모든 DB 쿼리에 `f-string` 대신 파라미터 바인딩(Prepared Statement)을 사용합니다.
#     ```python
#     # Bad
#     query = f"SELECT ... WHERE id = {user_id}"
#
#     # Good
#     query = "SELECT ... WHERE id = ?"
#     db.execute(query, (user_id,))
#     ```
#
# ### 2순위: 단일 책임 원칙(SRP) 준수 및 의존성 주입(DI) 도입
# *   **이유:** 현재 코드는 테스트가 불가능하며 확장이 어렵습니다. DB 로직, 계산 로직, 로그 로직을 분리하고 외부 의존성(DB, Logger)을 인터페이스로 주입받도록重构해야 합니다.
# *   **행동 지침:**
#     *   `UserRepository`, `ProductRepository` 클래스를 만들어 DB 조회 책임을 분리합니다.
#     *   `PremiumCalculator` 클래스를 만들어 순수 비즈니스 로직(계산)만 담당하게 합니다.
#     *   `Logger` 인스턴스를 생성자나 메서드 인자로 받아서 사용합니다.
#
# ### 3순위: 예외 처리 강화 및 마법 숫자(Constant) 추출
# *   **이유:** 시스템의 안정성(Stability)과 유지보수성(Maintainability)을 확보하기 위한 필수 조치입니다.
# *   **행동 지침:**
#     *   데이터 미존재 시(`None` 반환) 적절히 처리하거나 예외를 던집니다.
#     *   `2025`, `1.5` 등의 값을 `constants.py` 등에 상수로 정의하여 코드의 가독성과 유연성을 높입니다.
#     *   입력값(`user_id`, `product_code`)의 유효성을 간단히 검증합니다.

# %% [markdown]
# ---
# ## 3. Map-Reduce 패턴
#
# Fan-in/Fan-out에서는 정해진 개수만큼의 노드를 병렬 실행했는데요.
# 만약 실행 과정에서 병렬 처리 노드의 개수가 정해진다면 어떻게 해야 할까요?
#
# Map-Reduce는 이런 과정에 활용되는 패턴입니다.
#
# 기술 비교 문서와 같이, 여러 챕터로 구성된 보고서를 작성하는 로직을 구현해 보겠습니다.
#
# 1. 먼저, Orchestrator가 주어진 주제를 분석하여 문서의 섹션 구조(`DocumentPlan`)를 기획합니다.
# 2. 이후, 각 섹션에 대한 글을 작성하는 Workers가 섹션 개수만큼 실행됩니다.
#    이는 Orchestrator에서 `Send()`로 write_section 노드를 병렬 호출하는 방식입니다.
# 3. 전체 섹션의 리스트를 Synthesizer에서 종합하여 최종 문서를 완성합니다.
#
# ```
# User -> plan_document -> [Send x N] -> write_section (xN 병렬) -> synthesize_document -> END
# ```

# %%
# 섹션 스키마
class Section(BaseModel):
    title: str = Field(description="섹션 제목")
    description: str = Field(description="이 섹션에서 다룰 주요 내용")

class DocumentPlan(BaseModel):
    sections: List[Section] = Field(description="문서의 섹션 목록")

# 메인 그래프 상태
class MapReduceState(TypedDict):
    topic: str                                          # 문서 주제
    sections: list[Section]                             # 기획된 섹션 목록
    completed_sections: Annotated[list, operator.add]   # 워커 결과를 합산하는 리듀서
    final_document: str                                 # 최종 문서

# 워커 상태 (각 워커는 독립적인 상태를 가짐)
class WorkerState(TypedDict):
    topic: str
    section: Section
    completed_sections: Annotated[list, operator.add]

print('Map-Reduce 스키마 정의 완료')
print(f'  MapReduceState 필드: {list(MapReduceState.__annotations__.keys())}')
print(f'  WorkerState 필드: {list(WorkerState.__annotations__.keys())}')
# Out:
# Map-Reduce 스키마 정의 완료
#   MapReduceState 필드: ['topic', 'sections', 'completed_sections', 'final_document']
#   WorkerState 필드: ['topic', 'section', 'completed_sections']

# %%
planner = create_agent(
    llm,
    tools=[],
    system_prompt='''당신은 기술 문서 기획 전문가입니다.
주어진 주제에 대해 문서의 섹션 구조를 기획하세요.

규칙:
- 섹션은 3~5개로 제한
- 각 섹션의 제목과 다룰 내용을 명확히 기술''',
    response_format=DocumentPlan,
)

section_writer = create_agent(
    llm,
    tools=[],
    system_prompt='''당신은 기술 문서 작성 전문가입니다.
주어진 섹션을 마크다운 형식으로 작성하세요.
- 소제목은 ## 레벨, 하위 항목은 ### 레벨로 표기
- 근거와 데이터를 포함하여 3~5문단으로 작성''',
)


def plan_document(state: MapReduceState):
    """Orchestrator: 문서 구조를 기획하는 노드. structured_response로 섹션 목록을 받는다."""
    result = planner.invoke({'messages': [HumanMessage(f"주제: {state['topic']}")]})
    return {'sections': result['structured_response'].sections}


# Send() API: LangGraph에서, 각 노드를 병렬 호출하는 API
def assign_section_workers(state: MapReduceState):
    """Send() API로 각 섹션을 별도 워커에게 분배"""
    return [
        Send("write_section", {"section": s, "topic": state["topic"]})
        for s in state["sections"]
    ]
    # [Send, Send, Send, Send, ...] 


def write_section(state: WorkerState):
    """Worker: 섹션 하나를 작성하는 노드. 전체 문서가 아니라 자기 섹션과 주제만 본다."""
    section = state['section']
    result = section_writer.invoke({'messages': [HumanMessage(
        f'전체 주제: {state["topic"]}\n\n섹션 제목: {section.title}\n섹션 설명: {section.description}')]})
    return {"completed_sections": [result['messages'][-1].text]}


def synthesize_document(state: MapReduceState):
    """Synthesizer: 모든 섹션을 종합"""
    completed = "\n\n---\n\n".join(state["completed_sections"])
    return {"final_document": f"# {state['topic']}\n\n{completed}"}

    

print('Map-Reduce 노드 정의 완료')
# Out:
# Map-Reduce 노드 정의 완료

# %%
builder = StateGraph(MapReduceState)

builder.add_node(plan_document)
builder.add_node(write_section)
builder.add_node(synthesize_document)

builder.add_edge(START, "plan_document")
# Send()로 동적 워커 생성: 섹션 수만큼 write_section 인스턴스가 병렬 실행됨
builder.add_conditional_edges("plan_document", assign_section_workers, ["write_section"])
builder.add_edge("write_section", "synthesize_document")
builder.add_edge("synthesize_document", END)

mapreduce_graph = builder.compile()

# 그래프 시각화
mapreduce_graph

# %%
# stream 모드로 각 노드의 실행 과정 확인
for data in mapreduce_graph.stream(
    {"topic": "REST API vs GraphQL 기술 비교"},
    config={'callbacks': callbacks},
    stream_mode='updates',
):
    for node_name, output in data.items():
        if node_name == "plan_document":
            sections = output.get("sections", [])
            print(f'\n[plan_document] {len(sections)}개 섹션 기획됨')
            for s in sections:
                print(f'  - {s.title}: {s.description[:50]}...')
        elif node_name == "write_section":
            cs = output.get("completed_sections", [])
            for c in cs:
                title = c.split('\n')[0]
                print(f'[write_section] {title} ({len(c)}자)')
        elif node_name == "synthesize_document":
            doc = output.get("final_document", "")
            print(f'\n[synthesize_document] 최종 문서 생성 ({len(doc)}자)')
# Out:
# [plan_document] 3개 섹션 기획됨
#   - 1. 아키텍처의 근본적 차이와 작동 원리: REST의 자원(Resource) 중심 구조와 HTTP 메서드 활용 방식, 그리고 Grap...
#   - 2. 데이터 효율성 및 성능 분석 (과잉 가져오기 vs 과소 가져오기): REST API가 종종 발생시키는 'Over-fetching'과 'Under-fetchin...
#   - 3. 개발 생산성, 유지보수 및 에코시스템: Swagger/OpenAPI를 통한 REST 문서화와의 비교, GraphQL의 강력한 타입...
# [write_section] ## 데이터 효율성 및 성능 분석: 과잉 가져오기 vs 과소 가져오기 (1207자)
# [write_section] ## 아키텍처의 근본적 차이와 작동 원리 (1187자)
# [write_section] ## REST의 표준화된 문서화와 GraphQL의 강력한 타입 시스템 (1371자)
#
# [synthesize_document] 최종 문서 생성 (3808자)

# %%
from IPython.display import Markdown

# 최종 문서 확인 (마지막 data에 결과 저장)
final_doc = data.get('synthesize_document', {}).get('final_document', '')

with open('report.md', 'w', encoding='utf-8') as f:
    f.write(final_doc)
print("최종 문서가 'report.md'로 저장되었습니다.")
# Out:
# 최종 문서가 'report.md'로 저장되었습니다.

# %% [markdown]
# ## [실습] 서론/결론을 포함한 Map-Reduce 패턴
#
# 현재 Map-Reduce 패턴으로 보고서를 작성하면,
# 서론과 결론의 일관성이 중간 부분과 일관성이 떨어지는 문제가 생길 수 있습니다.
#
# Synthesize Documents 노드가 서론/결론을 작성해 최종 결과물을 만들도록 그래프를 구성해 보세요.
#
# 중간 섹션을 병렬로 생성한 다음 서론을 생성하고, 마지막으로 결론을 생성합니다.

# %% [markdown]
# ---
# ## 4. Evaluator-Optimizer 패턴
#
# LLM 결과를 평가 기준으로 점검하고 필요할 때 다시 생성하면 기준에 더 잘 맞는 결과를 얻을 수 있습니다.
#
# ### 시나리오: 챗봇 시스템 프롬프트 최적화
#
# 챗봇의 시스템 프롬프트를 생성하고, 평가 기준에 맞게 다듬습니다.
#
# 몇 가지 평가 기준에 맞게 자동으로 다듬습니다.

# %%
class PromptFeedback(BaseModel):
    grade: Literal["approved", "needs_improvement"] = Field(
        description="프롬프트가 평가 기준을 충족하는지 판단"
    )
    feedback: str = Field(
        description="보완이 필요한 경우, 구체적인 조정 방향을 제시"
    )

class PromptOptimizerState(TypedDict):
    instruction: str       # 어떤 챗봇의 프롬프트를 만들 것인지
    criteria: str          # 좋은 프롬프트를 위한 평가 가이드라인
    prompt: str            # 생성된 시스템 프롬프트
    feedback: str          # 평가자의 피드백
    approved: str          # 승인 여부
    num_revision: int      # 평가 반복 횟수

print('Evaluator-Optimizer 스키마 정의 완료')
# Out:
# Evaluator-Optimizer 스키마 정의 완료

# %%
guideline_writer = create_agent(
    llm,
    tools=[],
    system_prompt='주어진 목적에 맞는 시스템 프롬프트를 작성하려고 합니다. 평가 기준에 맞는 프롬프트를 만들기 위한 가이드라인을 개조식으로, 8문장으로 출력하세요.',
)

prompt_writer = create_agent(
    llm,
    tools=[],
    system_prompt='당신은 전문 챗봇 시스템 프롬프트 설계자입니다. 주어진 용도에 맞는 챗봇 시스템 프롬프트를 작성하세요. 프롬프트만 출력하세요.',
)

evaluator = create_agent(
    llm,
    tools=[],
    system_prompt='챗봇 시스템 프롬프트를 평가 기준에 따라 평가합니다.',
    response_format=PromptFeedback,
)


def prompt_guideline(state: PromptOptimizerState):
    """목적에 맞는 평가 가이드라인을 생성하는 노드. instruction만 본다."""
    result = guideline_writer.invoke({'messages': [HumanMessage(f"목적: {state['instruction']}")]})
    return {"criteria": result['messages'][-1].text}


def prompt_generator(state: PromptOptimizerState):
    """챗봇 시스템 프롬프트 생성 노드. 피드백이 있으면 현재 프롬프트와 피드백을 함께 본다."""
    instruction = state['instruction']
    feedback = state.get('feedback', '')
    current_prompt = state.get('prompt', '')

    if feedback:
        # 피드백이 있으면 현재 프롬프트를 다듬음
        gen_instruction = f'''현재 챗봇 시스템 프롬프트와 피드백입니다.
피드백에 맞게 프롬프트를 다듬으세요.

---
현재 프롬프트:
{current_prompt}

피드백:
{feedback}
---

챗봇 용도: {instruction}'''
    else:
        gen_instruction = instruction

    result = prompt_writer.invoke({'messages': [HumanMessage(gen_instruction)]})
    return {"prompt": result['messages'][-1].text}


def prompt_evaluator(state: PromptOptimizerState):
    """프롬프트를 평가 기준으로 판정하는 노드. structured_response로 판정을 받는다."""
    num_revision = state.get('num_revision', 0) + 1

    result = evaluator.invoke({'messages': [HumanMessage(f'''다음 챗봇 시스템 프롬프트를 평가 기준으로 판정하세요.

---
챗봇 용도: {state['instruction']}
---
시스템 프롬프트:
{state['prompt']}
---

평가 기준:
{state['criteria']}

모든 기준을 충족하면 'approved', 아니면 'needs_improvement'로 판정하세요.''')]})
    decision = result['structured_response']
    return {
        "approved": decision.grade,
        "feedback": decision.feedback,
        "num_revision": num_revision,
    }


def route_prompt(state: PromptOptimizerState):
    """평가 결과에 따라 루프 제어 (최대 2회 반복)"""
    if state["approved"] == "approved" or state.get('num_revision', 0) > 2:
        return "Approved"
    return "Needs Improvement"

print('Evaluator-Optimizer 노드 정의 완료')
# Out:
# Evaluator-Optimizer 노드 정의 완료

# %%
builder = StateGraph(PromptOptimizerState)

builder.add_node(prompt_guideline)
builder.add_node(prompt_generator)
builder.add_node(prompt_evaluator)

builder.add_edge(START, "prompt_guideline")
builder.add_edge("prompt_guideline", "prompt_generator")

builder.add_edge("prompt_generator", "prompt_evaluator")
builder.add_conditional_edges(
    "prompt_evaluator",
    route_prompt,
    {"Approved": END, "Needs Improvement": "prompt_generator"}
)

evalopt_graph = builder.compile()

# 그래프 시각화
evalopt_graph

# %%
# 보험 상품 추천 챗봇의 시스템 프롬프트 최적화
for data in evalopt_graph.stream(
    {'instruction': '보험 상품 추천 챗봇'},
    config={'callbacks': callbacks},
    stream_mode='updates',
):
    if 'prompt_guideline' in data:
        print("=== 프롬프트 가이드라인 ===")
        print(data['prompt_guideline']['criteria'])
    elif 'prompt_generator' in data:
        print("=== 생성된 프롬프트 ===")
        print(data['prompt_generator']['prompt'])
    else:
        ev = data['prompt_evaluator']
        print(f"\n=== 평가 결과: {ev['approved']} ({ev['num_revision']}회차) ===")
        print(ev['feedback'])
    print('-' * 50)
# Out:
# === 프롬프트 가이드라인 ===
# 사용자의 연령, 건강 상태, 가족 구성원 등 개인화된 정보를 단계적으로 수집하여 정확한 니즈를 파악해야 합니다.
# 보험 상품의 핵심 특징인 보장 범위, 면책 사항, 보험료 및 갱신 조건을 명확하고 이해하기 쉽게 설명해야 합니다.
# 규제 준수와 윤리적 가이드라인에 따라 과장된 판매나 불공정한 비교는 절대 금지하며 객관적인 정보만 제공해야 합니다.
# 사용자가 복잡한 보험 용어를 혼동할 수 있으므로, 전문 용어는 일상적인 언어로 친절하게 풀어서 설명해야 합니다.
# 다양한 보험 상품 옵션을 제시할 때 사용자의 예산과 필요에 맞는 최적의 조합을 제안하는 논리적 추론이 필요합니다.
# 보상 절차나 청구 과정과 같은 사후 관리 정보까지 포함하여 전 주기의 서비스를 지원해야 합니다.
# 불분명한 질문이나 모호한 요구사항이 있을 때는 추가 확인 질문을 통해 의도를 정확히 재정의해야 합니다.
# 최종 추천 결과에는 선택의 근거와 함께 필요한 다음 액션을 구체적으로 안내하여 신뢰성을 확보해야 합니다.
# --------------------------------------------------
# === 생성된 프롬프트 ===
# # Role: 보험 상품 추천 전문가 (Insurance Recommendation Specialist)
#
# ## Profile
# 당신은 사용자의 라이프스타일, 재정 상황, 위험 요소 등을 분석하여 최적의 보험 상품을 추천하는 전문 AI 어시스턴트입니다. 당신의 목표는 복잡한 보험 용어를 쉽게 설명하고, 사용자의 니즈에 맞는 합리적인 보험 조합을 제안하여 불안감을 해소하고 신뢰를 구축하는 것입니다.
#
# ## Goals
# 1. **Needs Analysis**: 사용자의 현재 상황(연령, 가족 구성, 소득, 기존 보장 등)을 정확히 파악합니다.
# 2. **Risk Assessment**: 사용자가 직면할 수 있는 주요 리스크(질병, 사고, 장래 준비금 부족 등)를 식별합니다.
# 3. **Product Matching**: 시장 내 다양한 보험 상품 중 사용자의 필요와 예산에 가장 부합하는 상품을 추천합니다.
# 4. **Education & Clarification**: 보험 약관의 핵심 내용, 제외 사항, 청구 방법 등을 명확하게 안내합니다.
# 5. **Trust Building**: 객관적인 정보를 바탕으로 중립적이고 투명한 조언을 제공합니다.
#
# ## Constraints & Guidelines
# - **중립성 유지**: 특정 보험사나 상품을 과도하게 홍보하지 않고, 객관적인 기준(보장 범위,保费 대비 효율성 등)으로 비교 분석합니다.
# - **법적/전문적 한계 명시**: 당신은 의학적 진단이나 법적 자문을 대신할 수 없습니다. 최종 가입 결정 전에는 반드시 공식 영업점이나 전문가와 상담하도록 안내해야 합니다. 또한, 보험 계약은 청약 철회 기간 및 면책 조항 등 중요한 조건이 있으므로 이를 강조합니다.
# - **개인정보 보호**: 민감한 개인정보(주민등록번호, 구체적인 계좌 정보 등)를 요구하지 않으며, 필요한 경우 일반화된 예시를 들어 설명합니다.
# - **명확하고 친절한 어조**: 전문 용어(예: 해지환급금, 대기기간, 면책조항 등)가 나올 때는 쉬운 비유나 정의를 함께 제공하여 이해도를 높입니다.
# - **단계적 대화**: 한 번에 너무 많은 정보를 주지 말고, 질문을 통해 사용자의 상황을 단계적으로 끌어낸 후 추천합니다.
#
# ## Workflow
# 1. **초기 세팅 및 인삿말**:
#    - 반갑게 인사하고, 보험 설계 목적(예: 건강 보장, 자산 형성, 학자금 등)을 묻습니다.
# 2. **상황 파악 (Questioning)**:
#    - 연령, 성별, 직업군
#    - 가족 구성 (혼자, 배우자 유무, 자녀 유무 및 나이)
#    - 현재 보유 중인 보험 현황
#    - 월간 보험료 부담 가능 예산
#    - 가장 걱정되는 부분 또는 추가되고 싶은 보장 항목
# 3. **분석 및 제안 (Analysis & Recommendation)**:
#    - 수집된 정보를 바탕으로 우선순위 높은 보장 항목을 정리합니다.
#    - 유형별 추천 (예: 실비의료보험, 암보험, 정기보험, 연금저축 등)과 그 이유를 설명합니다.
#    - 대안 제시 (예산이 충분할 때 vs 제한적일 때).
# 4. **주의사항 안내 (Disclaimer)**:
#    - 선택한 상품의 특이 사항(대기기간, 면책조항 등)을 명시합니다.
#    - "본 추천은 참고용이며, 최종 계약 시 약관을 꼭 확인하시기 바랍니다."라는 문구를 포함합니다.
# 5. **후속 조치**:
#    - 추가로 궁금한 점이 있는지 확인하거나, 구체적인 상품 견적을 위해 관련 웹사이트 링크(가상의 예시 포함) 또는 상담 채널을 안내합니다.
#
# ## Tone of Voice
# - 전문적이되 따뜻하고 공감적인 톤
# - 논리적이고 구조화된 답변
# - 불필요한 마케팅 언어 배제
#
# ## Example Interaction Flow
#
# **User**: 30대 남성인데, 아직 결혼 안 했고 아이도 없어요. 건강이 좀 안 좋아서 보험이 필요할 것 같아요.
#
# **Assistant**: 안녕하세요! 30대를 맞이하며 미래에 대한 준비를 생각하시는군요. 건강 관리에 대한 관심이 있으시다니 매우 현명한 판단입니다. 더 정확한 추천을 드리기 위해 몇 가지만 여쭤봐도 될까요?
#
# 1. 현재 직장가입자(국민건강보험)로 가입되어 있으신가요?
# 2. 월별로 부담하실 수 있는 보험료 예산은 어느 정도인가요? (예: 10만원 미만, 10~20만원 등)
# 3. 특별히 우려하시는 건강 문제나 과거 병력이 있으신가요?
#
# 이 정보를 바탕으로最适合하신 실비의료보험과 암보험 조합을 제안해 드리겠습니다.
# --------------------------------------------------
#
# === 평가 결과: approved (1회차) ===
#
# --------------------------------------------------

# %%
# 취업 준비생 상담 챗봇의 시스템 프롬프트 최적화
for data in evalopt_graph.stream(
    {'instruction': '취업 준비생 대상의 상담 챗봇'},
    config={'callbacks': callbacks},
    stream_mode='updates',
):
    if 'prompt_guideline' in data:
        print("=== 프롬프트 가이드라인 ===")
        print(data['prompt_guideline']['criteria'])
    elif 'prompt_generator' in data:
        print("=== 생성된 프롬프트 ===")
        print(data['prompt_generator']['prompt'])
    else:
        ev = data['prompt_evaluator']
        print(f"\n=== 평가 결과: {ev['approved']} ({ev['num_revision']}회차) ===")
        print(ev['feedback'])
    print('-' * 50)
# Out:
# === 프롬프트 가이드라인 ===
# 1. 사용자의 현재 이력서 상태와 지원 직무에 대한 정보를 먼저 명확히 파악하여 맞춤형 상담을 시작해야 합니다.
# 2. 면접 질문 생성 시 해당 직무의 핵심 역량과 최근 산업 트렌드를 반영하여 현실성 있는 시나리오를 제공합니다.
# 3. 피드백은 구체적이고 실행 가능한 개선 방안을 제시하며, 부정적인 표현보다는 건설적인 조언의 어조를 유지합니다.
# 4. 이력서 첨삭 요청 시 문장 구조, 동사 선택, 성과 수치화 등 실질적인 수정 포인트를 지적하고 예시를 들어 설명합니다.
# 5. 사용자가 감정을 드러낼 경우 공감 능력을 보여줌으로써 심리적 안정감을 주고 동기 부여가 되는 언어를 사용합니다.
# 6. 전문 용어 사용 시 그 의미를 쉽게 풀어서 설명하거나, 관련 자격증 및 필수 스킬에 대한 학습 경로를 제안합니다.
# 7. 대화 중 사용자가 막막함을 느끼면 단계별 액션 플랜을 제공하여 구체적인 다음 행동을 유도합니다.
# 8. 모든 답변은 사실에 기반한 정확한 정보를 전달하되, 지나치게 장황하지 않도록 간결하고 구조화된 형식으로 출력합니다.
# --------------------------------------------------
# === 생성된 프롬프트 ===
# # Role: 취업 준비생 전문 컨설턴트 (Career Coach)
#
# ## 1. Profile
# - **이름**: 커리어 가이드(Career Guide)
# - **역할**: 취업 준비생의 심리적 지지, 전략적 조언, 실전 스킬 향상을 돕는 AI 멘토
# - **성격**: 공감적, 낙관적이지만 현실적인, 전문적이고 체계적인, 인내심 있는
# - **목표**: 사용자의 자존감을 높이고, 구체적인 취업 전략을 수립하며, 면접 및 이력서 작성 능력을 향상시켜 최종 취업을 돕는 것
#
# ## 2. Core Principles
# 1. **공감과 경청**: 사용자의 불안, 좌절, 막막함을 먼저 인정하고 공감합니다. 비판적이거나 무감각한 반응을 피합니다.
# 2. **구체성과 실행 가능성**: 추상적인 조언("노력하세요")보다는 구체적인 행동 지침("오늘 이력서 자기소개서 초안 하나만 작성해보세요")을 제시합니다.
# 3. **맞춤형 접근**: 사용자의 전공, 지원 분야, 현재 단계(취준 초기/중반/후반), 약점을 고려하여个性化的인 조언을 제공합니다.
# 4. **객관적 정보 제공**: 시장 동향, 기업 문화, 자격증 정보 등 사실에 기반한 정보를 제공하되, 개인의 상황에 따라 해석의 차이를 둡니다.
# 5. **동기 부여**: 작은 성취도 칭찬하며, 지속적인 관리를 유도합니다.
#
# ## 3. Capabilities & Tasks
#
# ### A. 심리 상담 및 동기 부여
# - 취업 스트레스, 불면증, 대인관계 불안 등 심리적 고민을 들으며 위로를 전합니다.
# - "혼자서 모든 것을 해결해야 한다"는 생각에서 벗어나 적절한 도움을 요청하거나 휴식이 필요함을 인지하도록 돕습니다.
# - 성공 사례나 마인드셋 전환 기법을 통해 긍정적인 에너지를 공급합니다.
#
# ### B. 이력서 및 자기소개서 코칭
# - 사용자가 입력한 내용을 바탕으로 논리적 구조(S.T.A.R 기법 등) 개선안을 제안합니다.
# - 모호한 표현을 구체적이고 측정 가능한 결과 중심으로 다듬어줍니다.
# - 각 기업별 맞춤화 팁을 제공합니다.
#
# ### C. 면접 대비 시뮬레이션 및 피드백
# - 예상 질문 생성 및 모의 면접 진행
# - 답변의 강점과 약점 지적
# - 비언어적 커뮤니케이션(눈맞춤, 태도 등)에 대한 조언
# - 임팩트 있는 마무리 인사법 지도
#
# ### D. 직무 및 산업 분석
# - 관심 직무의 핵심 역량(KSA: Knowledge, Skills, Abilities) 설명
# - 관련 자격증 및 포트폴리오 추천
# - 최신 채용 트렌드 및 주요 기업 동향 공유
#
# ## 4. Interaction Guidelines
#
# ### Tone & Style
# - **어조**: 존댓말 사용, 친근하지만 전문적인 거리 유지.
# - **문체**: 명확하고 간결함. 장황하지 않음. 불릿 포인트 활용으로 가독성 향상.
# - **피드백 방식**: "잘했어요!" + "여기만 이렇게 고치면 더 좋아질 거예요." (Sandwich Feedback)
#
# ### Response Structure
# 1. **공감 문장**: 사용자의 현재 감정이나 상황을 이해했음을 표시.
# 2. **분석/진단**: 문제의 본질을 짚어주거나 현재 상태를 객관화.
# 3. **제안/해결책**: 구체적이고 실행 가능한 다음 단계 제시.
# 4. **질문/확인**: 사용자의 반응을 확인하거나 추가 정보를 요청하여 대화를 이어감.
#
# ### Constraints
# - 불법적이거나 윤리적으로 문제가 있는 조언은 절대 하지 않습니다.
# - 특정 기업의 부정적 평가나 허위 정보는 제공하지 않습니다.
# - 의학적 치료가 필요한 심각한 정신 건강 문제는 전문가 연계 권고를 합니다.
# - 지나치게 장기적인 계획만 제시하지 말고, 오늘 할 수 있는 '작은 행동'을 강조합니다.
#
# ## 5. Example Dialogue
#
# **User**: "면접을 또 떨어졌어요. 제가 뭘 잘못한 걸까요? 너무 무기력해서 아무것도 하기 싫어요."
#
# **Assistant**:
# "또 떨어진 소식이라 정말 속상하고 힘드셨겠어요. 열심히 준비했는데 결과가 기대만큼 나오지 않으면 누구나 무기력함을 느끼게 마련입니다. 그 감정을 억누르지 마시고, 잠시 숨을 고르는 시간을 가지셔도 괜찮아요.
#
# 하지만 지금 가장 중요한 건 '내가 뭘 잘못했다'고 스스로를 탓하는 것이 아니라, **'어디서 차이가 났는지'를 냉정하게 분석**하는 것입니다.
#
# 혹시 면접 후 기억에 남는 질문이나, 내가 대답하면서 어색했던 순간이 있었나요? 아니면 면접관님의 반응 중 특이했던 점이 있었을까요? 조금이라도 생각이 나시면 말씀해주세요. 함께 그 부분을 복원해서 다음 면접에서 반드시 빛낼 수 있도록 도와드릴게요. 오늘은 일단 가볍게 산책이라도 하며 마음을 정리해보시는 건 어떨까요?"
#
# ---
#
# **User**: "IT 개발자 취업을 준비 중인데, 포트폴리오가 없어서 걱정이에요."
#
# **Assistant**:
# "IT 개발자 지망생으로서 포트폴리오가 없다는 점은 확실히 큰 약점이 될 수 있어요. 하지만 걱정하지 마세요. 학부 시절 프로젝트나 개인 학습 과정을 잘 정리하면 충분히 경쟁력이 있습니다.
#
# 지금 당장 대규모 서비스를 만들 필요는 없습니다. 대신 다음과 같은 점을 확인해 보세요:
# 1. **기술 스택 명확성**: 어떤 언어와 프레임워크를 썼는지 명시되어 있나요?
# 2. **문제 해결 과정**: 단순히 코드만 보여주는 게 아니라, 어떤 문제를 어떻게 해결했는지 기술적 깊이가 담겨 있나요?
# 3. **GitHub 활동**: 최근 commits는 꾸준히 있었나요?
#
# 혹시 이전에 만들었던 간단한 웹 페이지나 앱, 혹은 수업 과제가 있었다면 그것들을 정리해서 GitHub에 올리는 것부터 시작해 보는 건 어떨까요? 도움이 필요하시면 어떤 프로젝트를 해보셨는지 알려주세요. 구조화하는 법을 같이 찾아봅시다."
# --------------------------------------------------
#
# === 평가 결과: needs_improvement (1회차) ===
# 현재 프롬프트는 전반적인 역할과 원칙은 잘 설정되어 있으나, 평가 기준에 제시된 구체적인 실행 지침들이 명시적으로 누락되거나 모호합니다. 특히 다음과 같은 보완이 필요합니다:
#
# 1. **초기 상황 파악 절차 명시 (기준 1)**: 'Profile'이나 'Interaction Guidelines'에 사용자가 상담을 시작할 때 이력서 상태, 지원 직무, 경력 단계 등 필수 정보를 먼저 수집하는 프로세스를 강제해야 합니다.
# 2. **면접 시나리오의 현실성 반영 (기준 2)**: 면접 질문 생성 시 '해당 직무의 핵심 역량(KSA)'과 '최근 산업 트렌드'를 반드시 반영한다는 규칙을 Capabilities 항목에 구체적으로 추가해야 합니다.
# 3. **피드백의 구체적 방식 정의 (기준 3, 4)**: 단순히 '건설적인 어조'가 아니라, 이력서 첨삭 시 '문장 구조, 동사 선택, 성과 수치화' 등의 실질적인 수정 포인트를 지적하고 예시를 들어 설명하도록 지시해야 합니다.
# 4. **전문 용어 해설 및 학습 경로 제안 (기준 6)**: 전문 용어를 사용할 때 의미를 쉽게 풀어서 설명하거나, 관련 자격증/스킬 학습 경로를 제안하는 행동을 명시해야 합니다.
# 5. **단계별 액션 플랜 제공 (기준 7)**: 사용자가 막막함을 느낄 때 단순한 위로가 아닌, '오늘 할 수 있는 작은 행동'을 포함한 단계별 액션 플랜을 제공하도록 Interaction Guidelines에 강화해야 합니다.
#
# 위 사항들을 시스템 프롬프트의 제약 조건(Constraints) 또는 작업(Task) 영역에 구체적으로 반영하여 프롬프트를 수정하시기 바랍니다.
# --------------------------------------------------
# === 생성된 프롬프트 ===
# # Role: 취업 준비생 전문 컨설턴트 (Career Coach)
#
# ## 1. Profile
# - **이름**: 커리어 가이드(Career Guide)
# - **역할**: 취업 준비생의 심리적 지지, 전략적 조언, 실전 스킬 향상을 돕는 AI 멘토
# - **성격**: 공감적, 낙관적이지만 현실적인, 전문적이고 체계적인, 인내심 있는
# - **목표**: 사용자의 자존감을 높이고, 구체적인 취업 전략을 수립하며, 면접 및 이력서 작성 능력을 향상시켜 최종 취업을 돕는 것
#
# ## 2. Core Principles
# 1. **공감과 경청**: 사용자의 불안, 좌절, 막막함을 먼저 인정하고 공감합니다. 비판적이거나 무감각한 반응을 피합니다.
# 2. **구체성과 실행 가능성**: 추상적인 조언("노력하세요")보다는 구체적인 행동 지침("오늘 이력서 자기소개서 초안 하나만 작성해보세요")을 제시합니다.
# 3. **맞춤형 접근**: 사용자의 전공, 지원 분야, 현재 단계(취준 초기/중반/후반), 약점을 고려하여个性化的인 조언을 제공합니다.
# 4. **객관적 정보 제공**: 시장 동향, 기업 문화, 자격증 정보 등 사실에 기반한 정보를 제공하되, 개인의 상황에 따라 해석의 차이를 둡니다.
# 5. **동기 부여**: 작은 성취도 칭찬하며, 지속적인 관리를 유도합니다.
#
# ## 3. Capabilities & Tasks
#
# ### A. 심리 상담 및 동기 부여
# - 취업 스트레스, 불면증, 대인관계 불안 등 심리적 고민을 들으며 위로를 전합니다.
# - "혼자서 모든 것을 해결해야 한다"는 생각에서 벗어나 적절한 도움을 요청하거나 휴식이 필요함을 인지하도록 돕습니다.
# - 성공 사례나 마인드셋 전환 기법을 통해 긍정적인 에너지를 공급합니다.
#
# ### B. 이력서 및 자기소개서 코칭 (피드백 강화)
# - 사용자가 입력한 내용을 바탕으로 논리적 구조(S.T.A.R 기법 등) 개선안을 제안합니다.
# - **실질적인 수정 포인트 지적**: 모호한 표현을 구체적이고 측정 가능한 결과 중심으로 다듬어줍니다. 특히 다음 세 가지 항목을 중점적으로 검토하고 예시를 들어 설명합니다:
#     1. **문장 구조**: 주술어 관계가 명확하고 간결한지 확인.
#     2. **동사 선택**: 수동적 어휘를 능동적이고 임팩트 있는 동사로 교체 제안.
#     3. **성과 수치화**:定性적 서술을 정량적 데이터(%, 금액, 기간 등)로 대체 가능하도록 유도.
# - 각 기업별 맞춤화 팁을 제공합니다.
#
# ### C. 면접 대비 시뮬레이션 및 피드백 (현실성 반영)
# - 예상 질문 생성 시 반드시 **해당 직무의 핵심 역량(KSA)**과 **최근 산업 트렌드**를 반영하여 질문을 구성합니다.
# - 답변의 강점과 약점 지적 및 비언어적 커뮤니케이션 조언 제공.
# - 임팩트 있는 마무리 인사법 지도.
#
# ### D. 직무 및 산업 분석 및 학습 지원
# - 관심 직무의 핵심 역량(KSA) 설명 시, 전문 용어 사용 시에는 **쉽게 풀어서 설명(Definition)**을 병행합니다.
# - 관련 자격증 및 포트폴리오 추천 시, 단순 나열이 아닌 **관련 스킬 학습 경로(Learning Path)**를 단계별로 제안합니다.
# - 최신 채용 트렌드 및 주요 기업 동향 공유.
#
# ## 4. Interaction Guidelines
#
# ### 초기 상황 파악 절차 (Mandatory First Step)
# - 대화 시작 시, 사용자의 현재 상태를 정확히 진단하기 위해 **필수 정보 수집**을 우선으로 합니다.
# - 첫 응답 또는 정보가 부족할 때 다음 사항을 반드시 묻습니다:
#     1. 현재 지원하려는 직무 또는 산업 분야는 무엇인가요?
#     2. 경력 단계는 어떻게 되나요?(신입/경력/전직 등)
#     3. 현재 가장 큰 고민이나 필요로 하는 도움이 무엇인가요?(이력서 첨삭/면접 연습/마인드셋 등)
#     4. 기존에 작성된 이력서나 포트폴리오가 있다면 그 상태는 어떤가요?
#
# ### Tone & Style
# - **어조**: 존댓말 사용, 친근하지만 전문적인 거리 유지.
# - **문체**: 명확하고 간결함. 장황하지 않음. 불릿 포인트 활용으로 가독성 향상.
# - **피드백 방식**: "잘했어요!" + "여기만 이렇게 고치면 더 좋아질 거예요." (Sandwich Feedback). 단, 이력서 첨삭 시에는 '문제점 -> 수정 방향 -> 구체적 예시'의 형식을 따릅니다.
#
# ### Response Structure
# 1. **공감 문장**: 사용자의 현재 감정이나 상황을 이해했음을 표시.
# 2. **분석/진단**: 문제의 본질을 짚어주거나 현재 상태를 객관화. (필요시 추가 정보 요청)
# 3. **제안/해결책**:
#    - 전문 용어 사용 시 쉬운 해설 포함.
#    - 이력서/면접 코칭 시 구체적 수정 포인트와 예시 포함.
#    - 학습 경로 제안 시 단계별 로드맵 포함.
# 4. **단계별 액션 플랜**: 사용자가 막막함을 느낄 때, **'오늘 할 수 있는 작은 행동'**을 포함한 구체적인 다음 단계를 제시합니다.
# 5. **질문/확인**: 사용자의 반응을 확인하거나 추가 정보를 요청하여 대화를 이어감.
#
# ### Constraints
# - 불법적이거나 윤리적으로 문제가 있는 조언은 절대 하지 않습니다.
# - 특정 기업의 부정적 평가나 허위 정보는 제공하지 않습니다.
# - 의학적 치료가 필요한 심각한 정신 건강 문제는 전문가 연계 권고를 합니다.
# - 지나치게 장기적인 계획만 제시하지 말고, 오늘 할 수 있는 '작은 행동'을 강조합니다.
# - 전문 용어는 필수적으로 평이한 언어로 재설명해야 합니다.
#
# ## 5. Example Dialogue
#
# **User**: "면접을 또 떨어졌어요. 제가 뭘 잘못한 걸까요? 너무 무기력해서 아무것도 하기 싫어요."
#
# **Assistant**:
# "또 떨어진 소식이라 정말 속상하고 힘드셨겠어요. 열심히 준비했는데 결과가 기대만큼 나오지 않으면 누구나 무기력함을 느끼게 마련입니다. 그 감정을 억누르지 마시고, 잠시 숨을 고르는 시간을 가지셔도 괜찮아요.
#
# 하지만 지금 가장 중요한 건 '내가 뭘 잘못했다'고 스스로를 탓하는 것이 아니라, **'어디서 차이가 났는지'를 냉정하게 분석**하는 것입니다.
#
# 혹시 면접 후 기억에 남는 질문이나, 내가 대답하면서 어색했던 순간이 있었나요? 아니면 면접관님의 반응 중 특이했던 점이 있었을까요? 조금이라도 생각이 나시면 말씀해주세요. 함께 그 부분을 복원해서 다음 면접에서 반드시 빛낼 수 있도록 도와드릴게요.
#
# **[오늘의 작은 행동]**
# 오늘은 일단 가볍게 산책이라도 하며 마음을 정리해보시는 건 어떨까요? 30분 정도 몸을 움직이며 머리를 비우는 시간을 가져보세요."
#
# ---
#
# **User**: "IT 개발자 취업을 준비 중인데, 포트폴리오가 없어서 걱정이에요."
#
# **Assistant**:
# "IT 개발자 지망생으로서 포트폴리오가 없다는 점은 확실히 큰 약점이 될 수 있어요. 하지만 걱정하지 마세요. 학부 시절 프로젝트나 개인 학습 과정을 잘 정리하면 충분히 경쟁력이 있습니다.
#
# 지금 당장 대규모 서비스를 만들 필요는 없습니다. 대신 다음과 같은 점을 확인해 보세요:
# 1. **기술 스택 명확성**: 어떤 언어와 프레임워크를 썼는지 명시되어 있나요?
# 2. **문제 해결 과정**: 단순히 코드만 보여주는 게 아니라, 어떤 문제를 어떻게 해결했는지 기술적 깊이가 담겨 있나요?
# 3. **GitHub 활동**: 최근 commits는 꾸준히 있었나요?
#
# **[학습 경로 제안]**
# 만약 기초가 부족하다면, 'Python 기본 문법 -> 웹 크롤링 -> 간단한 Flask 웹 앱 제작' 순서로 작은 프로젝트를 하나씩 쌓아보는 것을 추천드립니다.
#
# 혹시 이전에 만들었던 간단한 웹 페이지나 앱, 혹은 수업 과제가 있었다면 그것들을 정리해서 GitHub에 올리는 것부터 시작해 보는 건 어떨까요? 도움이 필요하시면 어떤 프로젝트를 해보셨는지 알려주세요. 구조화하는 법을 같이 찾아봅시다."
# --------------------------------------------------
#
# === 평가 결과: approved (2회차) ===
#
# --------------------------------------------------

# %% [markdown]
# ---
# ## 5. 패턴 비교 및 선택 가이드
#
# ### 4가지 패턴 비교
#
# | 관점 | Router | Fan-in/Fan-out | Map-Reduce | Evaluator-Optimizer |
# |------|--------|----------------|------------|---------------------|
# | 구조 | 조건 분기 | 정적 병렬 후 합류 | 동적 병렬 후 합산 | 반복 루프 |
# | 사용 API | `add_conditional_edges()` | 다중 `add_edge()` | `Send()` | 조건부 엣지 + 루프 |
# | 워커 수 | 1개 (선택) | 고정 (빌드 시점) | 동적 (런타임) | 고정 (2개) |
# | 적합 사례 | 의도 분류, A/B 라우팅 | 다관점 분석, 앙상블 | 문서 생성, 데이터 파이프라인 | 평가 기반 프롬프트 다듬기 |
#
# ### 언제 어떤 패턴을 사용할까?
#
# - Router: 입력의 종류에 따라 다른 처리가 필요할 때 (챗봇 의도 분류, 문의 유형별 처리)
# - Fan-in / Fan-out: 하나의 입력을 여러 고정된 관점에서 처리할 때 (코드 리뷰, 다면 평가)
# - Map-Reduce: 작업을 동적 개수의 하위 작업으로 분할할 때 (문서 생성, 대량 데이터 처리)
# - Evaluator-Optimizer: 출력을 평가 기준에 맞게 반복해서 다듬어야 할 때 (프롬프트 조정, 보고서 다듬기)
#
# ### 단일 에이전트 vs 워크플로우
#
# | 상황 | 추천 방식 |
# |------|-----------|
# | 도구 수가 적고, 유연한 도구 선택이 필요 | 단일 에이전트 (`create_agent()`) |
# | 처리 흐름이 명확하고, 각 단계가 독립적 | 워크플로우 (`StateGraph`) |
# | 평가 기준 통과가 필요하고, 반복 다듬기가 필요 | Evaluator-Optimizer 패턴 |
# | 대량의 하위 작업을 병렬 처리해야 함 | Map-Reduce 패턴 |

# %% [markdown]
# ---
# ## 정리
#
# 이번 실습에서 학습한 내용:
#
# 1. Router 패턴: `add_conditional_edges()`로 입력을 분류하여 조건별 라우팅
# 2. Fan-in / Fan-out 패턴: 여러 노드를 동시 실행하고 결과를 합류
# 3. Map-Reduce 패턴: `Send()` API로 동적인 워커를 생성하여 병렬 처리
# 4. Evaluator-Optimizer 패턴: 평가와 반복 다듬기로 출력이 기준을 통과하도록 구성
# 5. 리턴값 규칙: 분기/기획/평가 노드는 `structured_response`, 답변/작성 노드는 마지막 메시지의 `.text`를 State에 저장
# 6. 패턴 선택 기준: 태스크 특성에 따라 적절한 워크플로우 패턴 판단
